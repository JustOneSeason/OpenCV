# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img = cv2.imread('/content/gdrive/My Drive/Colab/Images/abcdef.bmp')
img = cv2.imread('/content/gdrive/My Drive/Colab/Images/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap = 'gray')
# Out:
# (256, 256)

# %%
hist = cv2.calcHist([gimg1], [0], None,[256],[0,255])
plt.plot(hist)

# %%
#img = cv2.imread('/content/gdrive/My Drive/Colab/Images/abcdef.bmp')
#img = cv2.imread('/content/gdrive/My Drive/Colab/Images/cell-bright.bmp')
#img = cv2.imread('/content/gdrive/My Drive/Colab/Images/cell.bmp')
img = cv2.imread('/content/gdrive/My Drive/Colab/Images/milkdrop.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap = 'gray')
# Out:
# (256, 256)

# %%
hist = cv2.calcHist([gimg1], [0], None,[256],[0,255])
plt.plot(hist)

# %%
gBin = np.zeros((gimg1.shape[0], gimg1.shape[1]))

# %%
T = 180

for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    if(gimg1[h,w]  > T):
      gBin[h,w] = 255
    else:
      gBin[h,w] = 0
cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
T1 = 50
T2 = 0
T0 = 1

outimg = np.zeros((gimg1.shape[0], gimg1.shape[1]))

# %%
def thershold_updata(img, output, T1):
  sum1 = 0
  count1 = 1
  sum2 = 0
  count2 = 1

  for h in range(img.shape[0]):
    for w in range(img.shape[1]):
      if(output[h,w] == 255):
        sum1 = sum1 + img[h,w]
        count1 = count1 + 1
      else:
        sum2 = sum2 + img[h,w]
        count2 = count2 +1

  avg1 = sum1/count1
  avg2 = sum2/count2

  T2= np.int32(avg1 + avg2)/2
  return T2

# %%
for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    if(gimg1[h,w] > T1):
        outimg[h,w]= 255
    else:
        outimg[h,w] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-16bc1a09ffaf> in <cell line: 1>()
#       1 for h in range(gimg1.shape[0]):
#       2   for w in range(gimg1.shape[1]):
# ----> 3     if(gimg1[h,w] > T1):
#       4         outimg[h,w]= 255
#       5     else:
#
# NameError: name 'T1' is not defined

# %%
while True:
    T2 = thershold_updata(gimg1, outimg, T1)

    if(np.abs(T1 - T2)< T0):
        for h in range(img.shape[0]):
          for w in range(img.shape[1]):
            if(gimg1[h,w] > T2) :
              outimg[h,w] = 255
            else:
              outimg[h,w] = 0
        break;
    else:
        T1 = T2
        for h in range(img.shape[0]):
          for w in range(img.shape[1]):
              if(gimg1[h,w] > T2) :
                outimg[h,w] = 255
              else:
                outimg[h,w] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9dc18115172b> in <cell line: 1>()
#       1 while True:
# ----> 2     T2 = thershold_updata(gimg1, outimg, T1)
#       3
#       4     if(np.abs(T1 - T2)< T0):
#       5         for h in range(img.shape[0]):
#
# NameError: name 'outimg' is not defined
